# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")
import seaborn as sns
from collections import Counter

# %%
file_path = '...titanic_dataset.csv'
train_df = pd.read_csv(file_path)

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.describe().T.style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_7e603_row0_col0, #T_7e603_row0_col1, #T_7e603_row0_col2, #T_7e603_row0_col3, #T_7e603_row0_col4, #T_7e603_row0_col5, #T_7e603_row0_col6, #T_7e603_row0_col7, #T_7e603_row1_col0, #T_7e603_row2_col0, #T_7e603_row2_col3, #T_7e603_row4_col0, #T_7e603_row5_col0, #T_7e603_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7e603_row1_col1, #T_7e603_row1_col2, #T_7e603_row1_col3, #T_7e603_row1_col4, #T_7e603_row1_col5, #T_7e603_row1_col6, #T_7e603_row1_col7, #T_7e603_row2_col2, #T_7e603_row2_col7, #T_7e603_row3_col0, #T_7e603_row4_col1, #T_7e603_row4_col2, #T_7e603_row4_col3, #T_7e603_row4_col4, #T_7e603_row4_col5, #T_7e603_row4_col6, #T_7e603_row5_col1, #T_7e603_row5_col2, #T_7e603_row5_col3, #T_7e603_row5_col4, #T_7e603_row5_col5, #T_7e603_row5_col6, #T_7e603_row6_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7e603_row2_col1, #T_7e603_row2_col5, #T_7e603_row2_col6, #T_7e603_row5_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7e603_row2_col4, #T_7e603_row4_col7 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7e603_row3_col1, #T_7e603_row3_col5 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7e603_row3_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_7e603_row3_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_7e603_row3_col4 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_7e603_row3_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7e603_row3_col7 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_7e603_row6_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_7e603_row6_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_7e603_row6_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_7e603_row6_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7e603_row6_col6 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7e603_row6_col7 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e603">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e603_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_7e603_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_7e603_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_7e603_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_7e603_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_7e603_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_7e603_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_7e603_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e603_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_7e603_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_7e603_row0_col1" class="data row0 col1" >446.000000</td>
#       <td id="T_7e603_row0_col2" class="data row0 col2" >257.353842</td>
#       <td id="T_7e603_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_7e603_row0_col4" class="data row0 col4" >223.500000</td>
#       <td id="T_7e603_row0_col5" class="data row0 col5" >446.000000</td>
#       <td id="T_7e603_row0_col6" class="data row0 col6" >668.500000</td>
#       <td id="T_7e603_row0_col7" class="data row0 col7" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_7e603_row1_col0" class="data row1 col0" >891.000000</td>
#       <td id="T_7e603_row1_col1" class="data row1 col1" >0.383838</td>
#       <td id="T_7e603_row1_col2" class="data row1 col2" >0.486592</td>
#       <td id="T_7e603_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_7e603_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_7e603_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_7e603_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_7e603_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_7e603_row2_col0" class="data row2 col0" >891.000000</td>
#       <td id="T_7e603_row2_col1" class="data row2 col1" >2.308642</td>
#       <td id="T_7e603_row2_col2" class="data row2 col2" >0.836071</td>
#       <td id="T_7e603_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_7e603_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_7e603_row2_col5" class="data row2 col5" >3.000000</td>
#       <td id="T_7e603_row2_col6" class="data row2 col6" >3.000000</td>
#       <td id="T_7e603_row2_col7" class="data row2 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_7e603_row3_col0" class="data row3 col0" >714.000000</td>
#       <td id="T_7e603_row3_col1" class="data row3 col1" >29.699118</td>
#       <td id="T_7e603_row3_col2" class="data row3 col2" >14.526497</td>
#       <td id="T_7e603_row3_col3" class="data row3 col3" >0.420000</td>
#       <td id="T_7e603_row3_col4" class="data row3 col4" >20.125000</td>
#       <td id="T_7e603_row3_col5" class="data row3 col5" >28.000000</td>
#       <td id="T_7e603_row3_col6" class="data row3 col6" >38.000000</td>
#       <td id="T_7e603_row3_col7" class="data row3 col7" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_7e603_row4_col0" class="data row4 col0" >891.000000</td>
#       <td id="T_7e603_row4_col1" class="data row4 col1" >0.523008</td>
#       <td id="T_7e603_row4_col2" class="data row4 col2" >1.102743</td>
#       <td id="T_7e603_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_7e603_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_7e603_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_7e603_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_7e603_row4_col7" class="data row4 col7" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_7e603_row5_col0" class="data row5 col0" >891.000000</td>
#       <td id="T_7e603_row5_col1" class="data row5 col1" >0.381594</td>
#       <td id="T_7e603_row5_col2" class="data row5 col2" >0.806057</td>
#       <td id="T_7e603_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_7e603_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_7e603_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_7e603_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_7e603_row5_col7" class="data row5 col7" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e603_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_7e603_row6_col0" class="data row6 col0" >891.000000</td>
#       <td id="T_7e603_row6_col1" class="data row6 col1" >32.204208</td>
#       <td id="T_7e603_row6_col2" class="data row6 col2" >49.693429</td>
#       <td id="T_7e603_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_7e603_row6_col4" class="data row6 col4" >7.910400</td>
#       <td id="T_7e603_row6_col5" class="data row6 col5" >14.454200</td>
#       <td id="T_7e603_row6_col6" class="data row6 col6" >31.000000</td>
#       <td id="T_7e603_row6_col7" class="data row6 col7" >512.329200</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
def bar_plot(variable):
    """
        input: variable ex: "Sex"
        output: bar plot & value count
    """
    # get feature
    var = train_df[variable]
    # count number of categorical variable(value/sample)
    var_value = var.value_counts()
    
    # visualize
    plt.figure(figsize = (9,3))
    plt.bar(var_value.index, var_value)
    plt.xticks(var_value.index, var_value.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,var_value))

# %%
category1 = ["Survived", "Sex", "Pclass", "Embarked", "SibSp", "Parch"]
for c in category1:
    bar_plot(c)
# Out:
# Survived:
#  Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# Sex:
#  Sex
# male      577
# female    314
# Name: count, dtype: int64
# Pclass:
#  Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# Embarked:
#  Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# SibSp:
#  SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
# Parch:
#  Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
category2 = ["Cabin", "Name", "Ticket"]
for c in category2:
    print("{} \n".format(train_df[c].value_counts()))
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64
#
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64
#
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
def plot_hist(variable):
    plt.figure(figsize = (9,3))
    plt.hist(train_df[variable], bins = 50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numeric_var = ["Fare", "Age","PassengerId"]
for n in numeric_var:
    plot_hist(n)

# %%
# Plcass vs Survived
train_df[["Pclass","Survived"]].groupby(["Pclass"], as_index = False).mean().sort_values(by="Survived",ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
# Sex vs Survived
train_df[["Sex","Survived"]].groupby(["Sex"], as_index = False).mean().sort_values(by="Survived",ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# Sibsp vs Survived
train_df[["SibSp","Survived"]].groupby(["SibSp"], as_index = False).mean().sort_values(by="Survived",ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
# Parch vs Survived
train_df[["Parch","Survived"]].groupby(["Parch"], as_index = False).mean().sort_values(by="Survived",ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
def detect_outliers(df,features):
    outlier_indices = []
    
    for c in features:
        # 1st quartile
        Q1 = np.percentile(df[c],25)
        # 3rd quartile
        Q3 = np.percentile(df[c],75)
        # IQR
        IQR = Q3 - Q1
        # Outlier step
        outlier_step = IQR * 1.5
        # detect outlier and their indeces
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        # store indeces
        outlier_indices.extend(outlier_list_col)
    
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 2)
    
    return multiple_outliers

# %%
train_df.loc[detect_outliers(train_df,["Age", "SibSp", "Parch", "Fare"])]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 27            28         0       1     Fortune, Mr. Charles Alexander    male
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 341          342         1       1     Fortune, Miss. Alice Elizabeth  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket    Fare        Cabin Embarked
# 27   19.0      3      2     19950  263.00  C23 C25 C27        S
# 88   23.0      3      2     19950  263.00  C23 C25 C27        S
# 159   NaN      8      2  CA. 2343   69.55          NaN        S
# 180   NaN      8      2  CA. 2343   69.55          NaN        S
# 201   NaN      8      2  CA. 2343   69.55          NaN        S
# 324   NaN      8      2  CA. 2343   69.55          NaN        S
# 341  24.0      3      2     19950  263.00  C23 C25 C27        S
# 792   NaN      8      2  CA. 2343   69.55          NaN        S
# 846   NaN      8      2  CA. 2343   69.55          NaN        S
# 863   NaN      8      2  CA. 2343   69.55          NaN        S

# %%
# drop outliers
outlier_indices = detect_outliers(train_df, ["Age", "SibSp", "Parch", "Fare"])
train_df = train_df.drop(outlier_indices, axis=0).reset_index(drop=True)

# %%
train_df_len = len(train_df)

# %%
train_df.columns[train_df.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
train_df[train_df["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 60            62         1       1                        Icard, Miss. Amelie
# 821          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 60   female  38.0      0      0  113572  80.0   B28      NaN
# 821  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_df.boxplot(column="Fare",by = "Embarked")
plt.show()

# %%
train_df["Embarked"] = train_df["Embarked"].fillna("C")
train_df[train_df["Embarked"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train_df[train_df["Fare"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train_df[train_df["Fare"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
list1 = ["SibSp", "Parch", "Age", "Fare", "Survived"]
sns.heatmap(train_df[list1].corr(), annot = True, fmt = ".2f")
plt.show()

# %%
g = sns.catplot(x = "SibSp", y = "Survived", data = train_df, kind = "bar")
g.set_ylabels("Survived Probability")
plt.show()

# %%
g = sns.catplot(x = "Parch", y = "Survived", kind = "bar", data = train_df)
g.set_ylabels("Survived Probability")
plt.show()

# %%
g = sns.catplot(x = "Pclass", y = "Survived", data = train_df, kind = "bar")
g.set_ylabels("Survived Probability")
plt.show()

# %%
g = sns.FacetGrid(train_df, col = "Survived")
g.map(sns.distplot, "Age", bins = 25)
plt.show()

# %%
g = sns.FacetGrid(train_df, col = "Survived", row = "Pclass")
g.map(plt.hist, "Age", bins = 25)
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(train_df, row = "Embarked")
g.map(sns.pointplot, "Pclass","Survived","Sex")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(train_df, row = "Embarked", col = "Survived")
g.map(sns.barplot, "Sex", "Fare")
g.add_legend()
plt.show()

# %%
train_df[train_df["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 27            29         1       3
# ..           ...       ...     ...
# 840          850         1       1
# 850          860         0       3
# 858          869         0       3
# 868          879         0       3
# 878          889         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 5                                Moran, Mr. James    male  NaN      0      0
# 17                   Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                        Masselmani, Mrs. Fatima  female  NaN      0      0
# 26                        Emir, Mr. Farred Chehab    male  NaN      0      0
# 27                  O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# ..                                            ...     ...  ...    ...    ...
# 840  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1      0
# 850                              Razi, Mr. Raihed    male  NaN      0      0
# 858                   van Melkebeke, Mr. Philemon    male  NaN      0      0
# 868                            Laleff, Mr. Kristo    male  NaN      0      0
# 878      Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 5        330877   8.4583   NaN        Q
# 17       244373  13.0000   NaN        S
# 19         2649   7.2250   NaN        C
# 26         2631   7.2250   NaN        C
# 27       330959   7.8792   NaN        Q
# ..          ...      ...   ...      ...
# 840       17453  89.1042   C92        C
# 850        2629   7.2292   NaN        C
# 858      345777   9.5000   NaN        S
# 868      349217   7.8958   NaN        S
# 878  W./C. 6607  23.4500   NaN        S
#
# [170 rows x 12 columns]

# %%
sns.catplot(x = "Sex", y = "Age", data = train_df, kind = "box")
plt.show()

# %%
sns.catplot(x = "Sex", y = "Age", hue = "Pclass",data = train_df, kind = "box")
plt.show()

# %%
sns.catplot(x = "Parch", y = "Age", data = train_df, kind = "box")
sns.catplot(x = "SibSp", y = "Age", data = train_df, kind = "box")
plt.show()

# %%
train_df['Sex'] = train_df['Sex'].map({'male': 0, 'female': 1})

corr_matrix = train_df[["Age", "Sex", "SibSp", "Parch", "Pclass"]].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

sns.heatmap(train_df[["Age","Sex","SibSp","Parch","Pclass"]].corr(), annot = True)
plt.show()

# %%
index_nan_age = list(train_df["Age"][train_df["Age"].isnull()].index)
for i in index_nan_age:
    sibsp_value = train_df.iloc[i]["SibSp"]
    parch_value = train_df.iloc[i]["Parch"]
    pclass_value = train_df.iloc[i]["Pclass"]
    
    condition = (train_df["SibSp"] == sibsp_value) & \
                (train_df["Parch"] == parch_value) & \
                (train_df["Pclass"] == pclass_value)
    
    age_pred = train_df.loc[condition, "Age"].median()
    age_med = train_df["Age"].median()
    
    if not np.isnan(age_pred):
        train_df.at[i, "Age"] = age_pred
    else:
        train_df.at[i, "Age"] = age_med

# %%
train_df[train_df["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
train_df["Fsize"] = train_df["SibSp"] + train_df["Parch"] + 1

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Fsize
# 0         A/5 21171   7.2500   NaN        S      2
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      1

# %%
g = sns.catplot(x = "Fsize", y = "Survived", data = train_df, kind = "bar")
g.set_ylabels("Survival")
plt.show()

# %%
train_df["family_size"] = [1 if i < 5 else 0 for i in train_df["Fsize"]]

# %%
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0  26.0      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Cabin Embarked  Fsize  family_size
# 0         A/5 21171   7.2500   NaN        S      2            1
# 1          PC 17599  71.2833   C85        C      2            1
# 2  STON/O2. 3101282   7.9250   NaN        S      1            1
# 3            113803  53.1000  C123        S      2            1
# 4            373450   8.0500   NaN        S      1            1
# 5            330877   8.4583   NaN        Q      1            1
# 6             17463  51.8625   E46        S      1            1
# 7            349909  21.0750   NaN        S      5            0
# 8            347742  11.1333   NaN        S      3            1
# 9            237736  30.0708   NaN        C      2            1

# %%
sns.countplot(x = "family_size", data = train_df)
plt.show()

# %%
g = sns.catplot(x = "family_size", y = "Survived", data = train_df, kind = "bar")
g.set_ylabels("Survival")
plt.show()

# %%
train_df = pd.get_dummies(train_df, columns= ["family_size"])
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Fsize  family_size_0  \
# 0         A/5 21171   7.2500   NaN        S      2          False
# 1          PC 17599  71.2833   C85        C      2          False
# 2  STON/O2. 3101282   7.9250   NaN        S      1          False
# 3            113803  53.1000  C123        S      2          False
# 4            373450   8.0500   NaN        S      1          False
#
#    family_size_1
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
train_df["Embarked"].head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
sns.countplot(x = "Embarked", data = train_df)
plt.show()

# %%
train_df = pd.get_dummies(train_df, columns=["Embarked"])
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Fsize  family_size_0  family_size_1  \
# 0         A/5 21171   7.2500   NaN      2          False           True
# 1          PC 17599  71.2833   C85      2          False           True
# 2  STON/O2. 3101282   7.9250   NaN      1          False           True
# 3            113803  53.1000  C123      2          False           True
# 4            373450   8.0500   NaN      1          False           True
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
sns.countplot(x = "Pclass", data = train_df)
plt.show()

# %%
train_df["Pclass"] = train_df["Pclass"].astype("category")
train_df = pd.get_dummies(train_df, columns= ["Pclass"])
train_df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare Cabin  Fsize  \
# 0    0  22.0      1      0         A/5 21171   7.2500   NaN      2
# 1    1  38.0      1      0          PC 17599  71.2833   C85      2
# 2    1  26.0      0      0  STON/O2. 3101282   7.9250   NaN      1
# 3    1  35.0      1      0            113803  53.1000  C123      2
# 4    0  35.0      0      0            373450   8.0500   NaN      1
#
#    family_size_0  family_size_1  Embarked_C  Embarked_Q  Embarked_S  Pclass_1  \
# 0          False           True       False       False        True     False
# 1          False           True        True       False       False      True
# 2          False           True       False       False        True     False
# 3          False           True       False       False        True      True
# 4          False           True       False       False        True     False
#
#    Pclass_2  Pclass_3
# 0     False      True
# 1     False     False
# 2     False      True
# 3     False     False
# 4     False      True

# %%
train_df["Sex"] = train_df["Sex"].astype("category")
train_df = pd.get_dummies(train_df, columns=["Sex"])
train_df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin  Fsize  family_size_0  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN      2          False
# 1  38.0      1      0          PC 17599  71.2833   C85      2          False
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN      1          False
# 3  35.0      1      0            113803  53.1000  C123      2          False
# 4  35.0      0      0            373450   8.0500   NaN      1          False
#
#    family_size_1  Embarked_C  Embarked_Q  Embarked_S  Pclass_1  Pclass_2  \
# 0           True       False       False        True     False     False
# 1           True        True       False       False      True     False
# 2           True       False       False        True     False     False
# 3           True       False       False        True      True     False
# 4           True       False       False        True     False     False
#
#    Pclass_3  Sex_0  Sex_1
# 0      True   True  False
# 1     False  False   True
# 2      True  False   True
# 3     False  False   True
# 4      True   True  False

# %%
train_df.drop(labels = ["PassengerId", "Cabin"], axis = 1, inplace = True)

# %%
train_df.columns
# Out:
# Index(['Survived', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Fsize',
#        'family_size_0', 'family_size_1', 'Embarked_C', 'Embarked_Q',
#        'Embarked_S', 'Pclass_1', 'Pclass_2', 'Pclass_3', 'Sex_0', 'Sex_1'],
#       dtype='object')
